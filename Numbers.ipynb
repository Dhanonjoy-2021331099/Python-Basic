# %%
#Random Number generate

import random

x = random.randrange(1,100)
print(x)
# Out:
# 69

# %%
a = 10     # int
b = 10.5  # float
c = 3 + 2j # complex
print(type(c))
print(c)
print(c.real)
print(c.imag)

sci = 2e15 # float
print(sci)
print(type(sci))
# Out:
# <class 'complex'>
# (3+2j)
# 3.0
# 2.0
# 2000000000000000.0
# <class 'float'>

# %%
# type conversiona 
a=10
b = float(a)  # 10.0
c = int(3.9)  # 3
d = complex(a)
print(b,  c,  d)
# Out:
# 10.0 3 (10+0j)

# %%
# Mathematical Operation 
x = 10
y = 3
print(x/y)   # 3.3333333333333335  float return
print(x//y)   # 3   # integer return
print(x%y)    # 1
print(2**4)   # 16  # 2^4
print(x*y)    #30
# Out:
# 3.3333333333333335
# 3
# 1
# 16
# 30
